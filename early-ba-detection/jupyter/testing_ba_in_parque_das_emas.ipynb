# %% [markdown]
# <div style="text-align: center;font-size: 90%;">
# <img src="inpe-grande.png" align="center" width=200/>
# </div>
#
# <div style="text-align: left;">
#     <a href="https://nbviewer.jupyter.org/github/brazil-data-cube/code-gallery/blob/master/jupyter/Python/stac/stac-introduction.ipynb"><img src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg" align="center"/></a>
# </div>
#
#
# <br/>
# <div style="text-align: center;font-size: 300%;">
# <span style="text-align: center; color:#ff3300">Burned Areas In Parque Nacional Das Emas</span>
# </div>
# <hr style="border:2px inset #ff9900 ;">

# %%
import sys
sys.path.append("/home/queimadas/git/my_fork/cap-423//early-ba-detection/module/")
from earlybadetection import early_ba_detection

# %%
pwd
# Out:
# '/home/queimadas/git/my_fork/cap-423/early-ba-detection/jupyter'

# %%
i=0
while i < 5:
    i+=1
    early_ba_detection(year=f'202{i}', tile='22KBE', cloud_porcentage=10)
    early_ba_detection(year=f'202{i}', tile='22KBF', cloud_porcentage=10)
    early_ba_detection(year=f'202{i}', tile='22KCE', cloud_porcentage=10)
    early_ba_detection(year=f'202{i}', tile='22KCF', cloud_porcentage=10)
    early_ba_detection(year=f'202{i}', tile='22LHH', cloud_porcentage=10)
# Out:
# /home/queimadas/miniconda3/envs/bdclab/lib/python3.10/site-packages/pystac_client/item_search.py:903: FutureWarning: get_all_items() is deprecated, use item_collection() instead.
#   warnings.warn(
# Processando assets: 0asset [00:00, ?asset/s]
# file 'early_burned_area_at_tile_22KBE_year_2021.json' saved!
# Processando assets: 0asset [00:00, ?asset/s]
# file 'early_burned_area_at_tile_22KBF_year_2021.json' saved!
# Processando assets: 0asset [00:00, ?asset/s]
# file 'early_burned_area_at_tile_22KCE_year_2021.json' saved!
# Processando assets: 0asset [00:00, ?asset/s]
# file 'early_burned_area_at_tile_22KCF_year_2021.json' saved!
# Processando assets: 0asset [00:00, ?asset/s]
# file 'early_burned_area_at_tile_22LHH_year_2021.json' saved!
# ...
